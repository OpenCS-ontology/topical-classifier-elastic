# %% [markdown]
# ## Querying an ES index with a batch of files
#
# This notebook demonstrates how to perform querying of an ES index with a given query for a batch of files.

# %% [markdown]
# Imports

# %%
from source.data.input_data_reading import get_all_input_file_paths
from config import INPUT_FILES_DIR, ONTOLOGY_CORE_DIR

from source.env_setup.setup import connect_elasticsearch 
from config import IDX_NAME, PORT
from source.ontology_parsing.graph_utils import get_concepts_pref_labels
from source.ontology_parsing.data_loading import get_all_concept_file_paths, get_graphs_from_files

from source.result_saving.handle_input_files import classify_input_files

# %% [markdown]
# Retrieving all files intended to be processed. An example vocabulary for an input article was delivered by the Web scrapping team.
# All inputs are stored in the `data/input_ttl_files`.
#
# The article's title and abstract should be present in the file, their URIs are specified in the `config.py` file.

# %%
input_files_paths = get_all_input_file_paths(INPUT_FILES_DIR)
input_files_paths
# Out:
# ['C:\\Users\\golik\\Desktop\\mgr\\semantic\\project\\opencs_paperclassification\\data\\input_ttl_files\\article0.ttl',
#  'C:\\Users\\golik\\Desktop\\mgr\\semantic\\project\\opencs_paperclassification\\data\\input_ttl_files\\article1.ttl',
#  'C:\\Users\\golik\\Desktop\\mgr\\semantic\\project\\opencs_paperclassification\\data\\input_ttl_files\\article2.ttl',
#  'C:\\Users\\golik\\Desktop\\mgr\\semantic\\project\\opencs_paperclassification\\data\\input_ttl_files\\article3.ttl']

# %% [markdown]
# Parsing the OpenCS ontology to get all concept names and preferred labels

# %%
# reading OpenCS files
files = get_all_concept_file_paths(ONTOLOGY_CORE_DIR)

# loading the files data into graphs with rdflib
graphs = get_graphs_from_files(files)

labels_to_concepts_names = get_concepts_pref_labels(graphs)
labels_to_concepts_names
# Out:
# {'C1': 'Computer science',
#  'C10': 'Algorithm',
#  'C100': 'Sequential optimization',
#  'C101': 'Knowledge based society',
#  'C102': 'Object matching',
#  'C103': 'Mixed variables',
#  'C104': 'Functional synthesis',
#  'C105': 'Simultaneous learning',
#  'C106': 'Traffic characteristic',
#  'C107': 'Rest break',
#  'C108': 'Nature inspired algorithm',
#  'C109': 'Naturalistic driving',
#  'C11': 'Embedded system',
#  'C110': 'Passive marker',
#  'C111': 'Visual feedback',
#  'C112': 'Reconfigurability',
#  'C113': 'Color response',
#  'C114': 'REEM',
#  'C115': 'crt0',
#  'C116': 'Team strategy',
#  'C117': 'Memory copy',
#  'C118': 'Test query',
#  'C119': 'Volumetric image',
#  'C12': 'Knowledge management',
#  'C120': 'Prosthetic hand',
#  'C121': 'Systems simulation',
#  'C122': 'Cellular automaton',
#  'C123': 'Digital filter',
#  'C124': 'Interrogative',
#  'C125': 'Next-generation network',
#  'C126': 'Logical consequence',
#  'C127': 'Bookmarking',
#  'C128': 'Global variable',
#  'C129': 'Functional capacity evaluation',
#  'C13': 'Data mining',
#  'C130': 'Instance selection',
#  'C131': 'Model management',
#  'C132': 'Java Interface Definition Language',
#  'C133': 'Williot diagram',
#  'C134': 'ClinicalKey',
#  'C135': 'Pro*C',
#  'C136': 'ThoughtTreasure',
#  'C137': 'Oracle BI server',
#  'C138': 'Reproduction speed',
#  'C139': 'Greedy source',
#  'C14': 'Computer engineering',
#  'C140': 'Web quality',
#  'C141': 'Continuous test-driven development',
#  'C142': 'Graphical language',
#  'C143': 'Information awareness',
#  'C144': 'Managing change',
#  'C145': 'Lead vehicle',
#  'C146': 'Automated learning',
#  'C147': 'Lexical bundles',
#  'C148': 'Game console',
#  'C149': 'Knowledge area',
#  'C15': 'Computer architecture',
#  'C150': 'Many to one',
#  'C151': 'Spatial methods',
#  'C152': 'Window model',
#  'C153': 'Restoration method',
#  'C154': 'Limiter',
#  'C155': 'Broadcast engineering',
#  'C156': 'Abstract machine',
#  'C157': 'ILLIAC',
#  'C158': 'Crosswind',
#  'C159': 'Timestamp',
#  'C16': 'Speech recognition',
#  'C160': 'Geometric primitive',
#  'C161': 'Method engineering',
#  'C162': 'Jaguar',
#  'C163': 'Communications law',
#  'C164': 'STARAN',
#  'C165': 'Information display systems',
#  'C166': 'Algorithm complexity',
#  'C167': 'Weapon system',
#  'C168': 'Numerical conditioning',
#  'C169': 'Algorithmic thinking',
#  'C17': 'Multimedia',
#  'C170': 'RS-449',
#  'C171': 'Data loss prevention software',
#  'C172': 'Austronesian languages',
#  'C173': 'OpenSafety',
#  'C174': 'restrict',
#  'C175': 'FITkit',
#  'C176': 'Hypermedia',
#  'C177': "Cromwell's rule",
#  'C178': 'Document classification',
#  'C179': 'Truchet tiles',
#  'C18': 'Human–computer interaction',
#  'C180': 'Speedcoding',
#  'C181': 'Pattern-of-life analysis',
#  'C182': 'Rhopalostylidinae',
#  'C183': 'String Value',
#  'C184': 'High call volume',
#  'C185': 'Sports arena',
#  'C186': 'Reaction timing',
#  'C187': 'Temporal similarity',
#  'C188': 'Speaking style',
#  'C189': 'Ordered set',
#  'C19': 'Programming language',
#  'C190': 'Multi layer network',
#  'C191': 'Antenna isolation',
#  'C192': 'Road condition',
#  'C193': 'Location aware',
#  'C194': 'Playful learning',
#  'C195': 'Cluttering',
#  'C196': 'Cassowary',
#  'C197': 'Information technology',
#  'C198': 'Distributed algorithm',
#  'C199': 'Pattern recognition (psychology)',
#  'C2': 'Computer hardware',
#  'C20': 'Computational science',
#  'C200': 'Model-based design',
#  'C201': 'Live action',
#  'C202': 'SAFER',
#  'C203': 'Radio modem',
#  'C204': 'Carroll diagram',
#  'C205': 'TRAK',
#  'C206': 'Therefore sign',
#  'C207': 'Little Smalltalk',
#  'C208': 'Conventional weapon',
#  'C209': 'Provider-independent address space',
#  'C21': 'Pattern recognition',
#  'C210': 'Flip-flop',
#  'C211': 'Collaborative innovation network',
#  'C212': 'Vocal articulation',
#  'C213': 'Polyglot Dictionary',
#  'C214': 'Police vehicle',
#  'C215': 'POSTURE ABNORMALITY',
#  'C216': 'Interval Sequence',
#  'C217': 'Minimal knowledge',
#  'C218': 'Assistive equipment',
#  'C219': 'Error mitigation',
#  'C22': 'Computer graphics (images)',
#  'C220': 'Reserved word',
#  'C221': 'ChromaDepth',
#  'C222': 'Data processing system',
#  'C223': 'Dynamical simulation',
#  'C224': 'Log trigger',
#  'C225': 'Metatheorem',
#  'C226': 'Discrete rate simulation',
#  'C227': 'Learner-generated context',
#  'C228': 'Debugging data format',
#  'C229': 'Intel 850',
#  'C23': 'Information retrieval',
#  'C230': 'Centralized database',
#  'C231': 'FIRST Award',
#  'C232': 'Registration status',
#  'C233': 'Verified procedure',
#  'C234': 'Vision algorithms',
#  'C235': 'Real time design',
#  'C236': 'String analysis',
#  'C237': 'Data recording',
#  'C238': 'Knowledge change',
#  'C239': 'Algebraic error',
#  'C24': 'Simulation',
#  'C240': 'Color structure',
#  'C241': 'Problem difficulty',
#  'C242': 'Organisational change',
#  'C243': 'Multi aspect',
#  'C244': 'Stereo display',
#  'C245': 'Digital artifact',
#  'C246': 'Conditional probability',
#  'C247': 'Overlap coefficient',
#  'C248': 'Facial recognition system',
#  'C249': 'Human Proteome Folding Project',
#  'C25': 'Machine learning',
#  'C250': 'Cognitive traps for intelligence analysis',
#  'C251': 'Ringing artifacts',
#  'C252': 'Exportation',
#  'C253': 'Fractal-generating software',
#  'C254': 'Electronic design automation',
#  'C255': 'Yarrow algorithm',
#  'C256': 'Colour banding',
#  'C257': 'Filter (signal processing)',
#  'C258': 'NuBus',
#  'C259': 'Finalization',
#  'C26': 'Computer network',
#  'C260': 'Autoregressive model',
#  'C261': 'Intelligent sensor',
#  'C262': 'Bibliome',
#  'C263': 'Personalization',
#  'C264': 'Query language',
#  'C265': 'Ctrie',
#  'C266': 'IEEE 802.1ag',
#  'C267': 'Granular synthesis',
#  'C268': 'Classification System for Serial Criminal Patterns',
#  'C269': 'Vetting',
#  'C27': 'Parallel computing',
#  'C270': 'Contact manager',
#  'C271': 'Security community',
#  'C272': 'Octal game',
#  'C273': 'Temporary folder',
#  'C274': 'Real world data',
#  'C275': 'Rice distribution',
#  'C276': 'Duplex system',
#  'C277': 'Zero norm',
#  'C278': 'Engineering psychology',
#  'C279': 'Unified messaging',
#  'C28': 'Software engineering',
#  'C280': 'Cut, copy, and paste',
#  'C281': 'Loran-C',
#  'C282': 'Virtual artifact',
#  'C283': 'Stack machine',
#  'C284': 'Date.start',
#  'C285': 'Spiders web',
#  'C286': 'History general',
#  'C287': 'Rapides Parish',
#  'C288': 'Component Concept',
#  'C289': 'Constraint specification',
#  'C29': 'Theoretical computer science',
#  'C290': 'Spatial similarity',
#  'C291': 'Error equation',
#  'C292': 'Mode change',
#  'C293': 'Data simulation',
#  'C294': 'Network geometry',
#  'C295': 'Traffic awareness',
#  'C296': 'Reference function',
#  'C297': 'Library design',
#  'C298': 'Audio recognition',
#  'C299': 'Plant models',
#  'C3': 'Telecommunications',
#  'C30': 'Distributed computing',
#  'C300': 'Real time mapping',
#  'C301': 'Iterative framework',
#  'C302': 'Tagged Command Queuing',
#  'C303': 'Yet another',
#  'C304': 'Postgenderism',
#  'C305': 'KISS (TNC)',
#  'C306': 'Information design',
#  'C307': 'TRADACOMS',
#  'C308': 'Phonetics',
#  'C309': 'Flight number',
#  'C31': 'World Wide Web',
#  'C310': 'Spatial intelligence',
#  'C311': 'CAPTCHA',
#  'C312': 'Latent semantic analysis',
#  'C313': 'Ideation',
#  'C314': 'Remote patient monitoring',
#  'C315': 'Boundary spanning',
#  'C316': 'Bayesian poisoning',
#  'C317': 'Space Network',
#  'C318': 'Annotation',
#  'C319': 'Separation of presentation and content',
#  'C32': 'Natural language processing',
#  'C320': 'Arpabet',
#  'C321': 'Matching person and technology model',
#  'C322': 'Double boot',
#  'C323': 'Tip of the day',
#  'C324': 'Adaptive heap sort',
#  'C325': 'Noisy text',
#  'C326': 'Instabus',
#  'C327': 'Strongtalk',
#  'C328': 'Computer file',
#  'C329': 'Dynamic dispatch',
#  'C33': 'Real-time computing',
#  'C330': 'L-carrier',
#  'C331': 'Normal mapping',
#  'C332': 'HTML sanitization',
#  'C333': 'Multimedia framework',
#  'C334': 'Card image',
#  'C335': 'Visual Feedbacks',
#  'C336': 'Normal postures',
#  'C337': 'Monocular indirect ophthalmoscope',
#  'C338': 'Acknowledgment code',
#  'C339': 'Internal ID',
#  'C34': 'Data science',
#  'C340': 'TRACK FIELD',
#  'C341': 'Subjective observation',
#  'C342': 'Four alternative auditory feature test',
#  'C343': 'Geographic state',
#  'C344': 'Sky-diving',
#  'C345': 'Virtual sensors',
#  'C346': 'Team decision making',
#  'C347': 'Assembly planning',
#  'C348': 'Brute force',
#  'C349': 'Model exchange',
#  'C35': 'Computer security',
#  'C350': 'Scale estimation',
#  'C351': 'Learning problem',
#  'C352': 'Testbed',
#  'C353': 'Rational agent',
#  'C354': 'Chip art',
#  'C355': 'HTML5',
#  'C356': 'Outside plant',
#  'C357': 'Robotics suite',
#  'C358': 'Call-tracking software',
#  'C359': 'Processing priority',
#  'C36': 'PACX',
#  'C360': 'Uralic language',
#  'C361': 'Checkerboard pattern',
#  'C362': 'Cost Measures',
#  'C363': 'Agricultural chemists',
#  'C364': 'Imaging problem',
#  'C365': 'Monitoring status',
#  'C366': 'Single objective',
#  'C367': 'Exhaustive search algorithm',
#  'C368': 'Process adaptation',
#  'C369': '3d tracking',
#  'C37': 'Flood fill',
#  'C370': 'User oriented',
#  'C371': 'Digital video disc',
#  'C372': 'Program evolution',
#  'C373': 'Common code',
#  'C374': 'Pattern vector',
#  'C375': 'Plane equation',
#  'C376': 'Dimension estimation',
#  'C377': 'Language bias',
#  'C378': 'Player game',
#  'C379': 'File server',
#  'C38': 'Dual-band blade antenna',
#  'C380': 'Teletex',
#  'C381': 'Experience curve effects',
#  'C382': 'Advanced Mobile Telephone System',
#  'C383': 'Scatter plot',
#  'C384': 'Evacuation process simulation',
#  'C385': 'Information structure',
#  'C386': 'Pattern matching',
#  'C387': 'Cocktail party effect',
#  'C388': 'Jenks natural breaks optimization',
#  'C389': 'Unit of time',
#  'C39': 'Digitization',
#  'C390': 'Network packet',
#  'C391': 'Bionz',
#  'C392': 'Baselining',
#  'C393': 'Fragmentation (computing)',
#  'C394': 'Identity theft',
#  'C395': 'Digital rights',
#  'C396': 'Von Neumann cellular automaton',
#  'C397': 'Semaphore Flag Signaling System',
#  'C398': 'CISQ',
#  'C399': 'Video email',
#  'C4': 'Library science',
#  'C40': 'Voice interface card',
#  'C400': 'STU-III',
#  'C401': 'Urdu',
#  'C402': 'Augmentative and alternative communication',
#  'C403': 'Completion rate',
#  'C404': 'Vocabulary-based transformation',
#  'C405': 'Compound Document Format',
#  'C406': 'Impact factor',
#  'C407': 'Simplex signaling',
#  'C408': 'The Blob',
#  'C409': 'Blanketing',
#  'C41': 'Student competition',
#  'C410': 'Second-order cellular automaton',
#  'C411': 'Bivariate analysis',
#  'C412': 'Private information retrieval',
#  'C413': 'Contour segment',
#  'C414': 'Process guidance',
#  'C415': 'Entity type',
#  'C416': 'Single frame',
#  'C417': 'Contrast enhancement',
#  'C418': 'Limited service',
#  'C419': 'Fully automatic',
#  'C42': 'AngelScript',
#  'C420': 'Videoconferencing',
#  'C421': 'Liquid consonant',
#  'C422': 'Image stitching',
#  'C423': 'Pseudo-wire',
#  'C424': 'Boosting (machine learning)',
#  'C425': 'Documentation',
#  'C426': 'Knights of the Lambda Calculus',
#  'C427': 'KISS principle',
#  'C428': 'Search engine indexing',
#  'C429': 'Sequent',
#  'C43': 'Collection catalog',
#  'C430': 'Development environment',
#  'C431': 'Conditional random field',
#  'C432': 'False position method',
#  'C433': 'Delay calculation',
#  'C434': 'Optophone',
#  'C435': 'Traffic calming',
#  'C436': 'Situational knowledge',
#  'C437': 'User agent',
#  'C438': 'Service allocation',
#  'C439': 'Research stream',
#  'C44': 'Amiga',
#  'C440': 'Carrier signal',
#  'C441': 'Mnemonic link system',
#  'C442': 'Disassembler',
#  'C443': 'Network socket',
#  'C444': 'Content adaptation',
#  'C445': 'Material Design',
#  'C446': 'Grand Challenges',
#  'C447': 'Online database',
#  'C448': 'Master of Information Management',
#  'C449': 'SAML 1.1',
#  'C45': 'Layout engine',
#  'C450': 'Systems Management Architecture for Server Hardware',
#  'C451': 'Parallel generation',
#  'C452': 'Mass call event',
#  'C453': 'Use walkers',
#  'C454': 'Repeated speech',
#  'C455': 'Network discovery',
#  'C456': 'Child computer interaction',
#  'C457': 'Tactile display',
#  'C458': 'Signal tracking',
#  'C459': 'Design for diagnosis',
#  'C46': 'Check mark',
#  'C460': 'Facial analysis',
#  'C461': 'Telephone switching',
#  'C462': 'Empirical error',
#  'C463': 'Time series simulation',
#  'C464': 'NETVC',
#  'C465': 'Confluence',
#  'C466': 'Snit',
#  'C467': 'Combat readiness',
#  'C468': 'IBM 3270 PC',
#  'C469': 'Battlefield Extraction-Assist Robot',
#  'C47': 'Programming method',
#  'C470': 'Score following',
#  'C471': "Rock's law",
#  'C472': 'Physical plant',
#  'C473': 'Information sharing',
#  'C474': 'Wireless supplicant',
#  'C475': 'Artificial intelligence for video surveillance',
#  'C476': 'Security printing',
#  'C477': 'SMPTE ST 2071',
#  'C478': 'Secrecy of correspondence',
#  'C479': 'Bus Pirate',
#  'C48': 'Tactile Senses',
#  'C480': 'Origination',
#  'C481': 'Bit-flipping attack',
#  'C482': 'Mindpixel',
#  'C483': 'Card (document)',
#  'C484': 'Associated party',
#  'C485': 'Computer network technology',
#  'C486': 'Report (document)',
#  'C487': 'Participant id',
#  'C488': 'Link generation',
#  'C489': 'Terminal punctuation',
#  'C49': 'St. James Parish',
#  'C490': 'Ethernet',
#  'C491': 'Empirical modelling',
#  'C492': 'System identification',
#  'C493': 'System level optimization',
#  'C494': 'Data entry',
#  'C495': 'Network testing',
#  'C496': 'Air combat',
#  'C497': 'Visual surveillance',
#  'C498': 'Confidence score',
#  'C499': 'Block entropy',
#  'C5': 'Internet privacy',
#  'C50': 'Hallucinate',
#  'C500': 'Video lecture',
#  'C501': 'Rule processing',
#  'C502': 'Error criteria',
#  'C503': 'Error separation',
#  'C504': 'Multiscale optimization',
#  'C505': 'Combat simulation',
#  'C506': 'Directed line',
#  'C507': 'Weighted entropy',
#  'C508': 'Contour following',
#  'C509': 'Time information',
#  'C51': 'Shape space',
#  'C510': 'Speech input',
#  'C511': 'Avionics',
#  'C512': 'Band I',
#  'C513': 'Constrained optimization',
#  'C514': 'Here document',
#  'C515': 'Communications system',
#  'C516': 'Spatial logic',
#  'C517': 'Information integrity',
#  'C518': 'Logical process',
#  'C519': 'Logical rules',
#  'C52': 'Content retrieval',
#  'C520': 'Sound recording and reproduction',
#  'C521': 'Backplane',
#  'C522': 'Trusted third party',
#  'C523': 'Deblocking filter',
#  'C524': 'Formal language',
#  'C525': 'Tracking system',
#  'C526': 'Turned A',
#  'C527': 'Spaghetti sort',
#  'C528': 'Uncertainty analysis',
#  'C529': 'Warped linear predictive coding',
#  'C53': 'Design framework',
#  'C530': 'Supervisor Mode Access Prevention',
#  'C531': 'Request–response',
#  'C532': 'Sussman Anomaly',
#  'C533': 'Industry 4.0',
#  'C534': 'Morph target animation',
#  'C535': 'i-number',
#  'C536': 'Small data',
#  'C537': 'Encryption layer in storage stack',
#  'C538': 'Long-exposure photography',
#  'C539': 'Suffix',
#  'C54': 'Multimedia information',
#  'C540': 'Sales force management system',
#  'C541': 'X-ray vision',
#  'C542': 'Mill architecture',
#  'C543': 'Bit banging',
#  'C544': 'Color enhancement',
#  'C545': 'Internet of Things',
#  'C546': 'Entropy (information theory)',
#  'C547': 'Stereo processing',
#  'C548': 'Transparent display',
#  'C549': 'Cross cultural collaboration',
#  'C55': 'Speech retrieval',
#  'C550': 'Time data',
#  'C551': 'Computer aided testing',
#  'C552': 'Toy industry',
#  'C553': 'Decision agent',
#  'C554': 'Rational tree',
#  'C555': 'Train driver',
#  'C556': 'Dual network',
#  'C557': 'Tree distance',
#  'C558': 'Uncertainty function',
#  'C559': 'Discourse connectives',
#  'C56': 'Object label',
#  'C560': 'Hearing research',
#  'C561': 'Organisation theory',
#  'C562': 'Equality relation',
#  'C563': 'Bernoulli model',
#  'C564': 'Tumor detection',
#  'C565': 'Virtual target',
#  'C566': 'Texas Instruments LPC Speech Chips',
#  'C567': 'Backward compatibility',
#  'C568': 'Light Weight Kernel Threads',
#  'C569': 'Instrument error',
#  'C57': 'Orchestration',
#  'C570': 'Happy path',
#  'C571': 'State space equation',
#  'C572': '3d mapping',
#  'C573': 'Management environment',
#  'C574': 'Natural Language Semantics Markup Language',
#  'C575': 'TCP reset attack',
#  'C576': 'BLISS',
#  'C577': 'Hard disk recorder',
#  'C578': 'OLE Automation',
#  'C579': 'Contour set',
#  'C58': 'HCS clustering algorithm',
#  'C580': 'Online tutoring',
#  'C581': 'Mathematical Calculus',
#  'C582': 'Manufacturer name',
#  'C583': 'Object Relationship',
#  'C584': 'Document URL',
#  'C585': 'Visual Focusing',
#  'C586': 'Helmet worn',
#  'C587': 'Multi processor',
#  'C588': 'User engagement',
#  'C589': 'State evolution',
#  'C59': 'Behavior Trees',
#  'C590': 'Textual information',
#  'C591': 'Vehicle safety',
#  'C592': 'Social machines',
#  'C593': 'Path number',
#  'C594': 'Integrity check',
#  'C595': 'Internal time',
#  'C596': 'Data market',
#  'C597': 'Bibcode',
#  'C598': 'Use of technology',
#  'C599': 'Business band',
#  'C6': 'Database',
#  'C60': 'Routing model',
#  'C600': 'Advanced Format',
#  'C601': 'Confidence assessment',
#  'C602': 'Interactive presentation',
#  'C603': 'Communication language',
#  'C604': 'Phase variance',
#  'C605': 'Team climate',
#  'C606': 'Point object',
#  'C607': 'CNET Video',
#  'C608': 'Preorder',
#  'C609': 'Systems analysis',
#  'C61': 'Communications management',
#  'C610': 'Ensemble learning',
#  'C611': 'Analysis of algorithms',
#  'C612': 'Reservehandverfahren',
#  'C613': 'Kilobit',
#  'C614': 'Gunfire locator',
#  'C615': 'Model View ViewModel',
#  'C616': 'UMTS frequency bands',
#  'C617': 'Network model',
#  'C618': 'Laster Technologies',
#  'C619': 'Parameterized complexity',
#  'C62': 'Image display',
#  'C620': 'Escrow',
#  'C621': 'Recovery time actual',
#  'C622': 'Animation',
#  'C623': 'Dependency relation',
#  'C624': 'Inhabited set',
#  'C625': 'IEEE 1613',
#  'C626': 'Goal decomposition',
#  'C627': 'Image averaging',
#  'C628': 'Algorithmic logic',
#  'C629': 'Pseudoeurycea unguidentis',
#  'C63': 'Numerical testing',
#  'C630': 'Reis telephone',
#  'C631': 'Handshake',
#  'C632': 'XCore XS1-G4',
#  'C633': 'VOLMET',
#  'C634': 'Mobility management',
#  'C635': 'Remote operation',
#  'C636': 'Sass',
#  'C637': 'Cursive',
#  'C638': 'Ladder-DES',
#  'C639': 'Architectural rendering',
#  'C64': 'Civic technology',
#  'C640': 'Universal Design for Learning',
#  'C641': 'Alexanderson Day',
#  'C642': 'Cross-functional team',
#  'C643': 'Assigning authority',
#  'C644': 'CAPABLE protocol',
#  'C645': 'Attitude testing',
#  'C646': 'Order document',
#  'C647': 'Voice functions',
#  'C648': 'Optimal cost',
#  'C649': 'Team working',
#  'C65': 'Knowledge structure',
#  'C650': 'Virtual agent',
#  'C651': 'Knowledge acquisition',
#  'C652': 'Urban mapping',
#  'C653': 'Computer monitor',
#  'C654': 'Misinformation',
#  'C655': 'Limited angle',
#  'C656': 'Node splitting',
#  'C657': 'Artifact suppression',
#  'C658': 'Filter design',
#  'C659': 'Simula',
#  'C66': 'Motion direction',
#  'C660': 'Flight simulator',
#  'C661': 'Common Object Request Broker Architecture',
#  'C662': 'Robust statistics',
#  'C663': 'Visual comparison',
#  'C664': '2D to 3D conversion',
#  'C665': 'Chain of custody',
#  'C666': 'Iterative and incremental development',
#  'C667': 'Technical illustration',
#  'C668': 'Layout manager',
#  'C669': 'Noise reduction',
#  'C67': 'Vehicle guidance',
#  'C670': 'Ground speed',
#  'C671': 'Connection string',
#  'C672': 'Collaborative software',
#  'C673': 'Stable storage',
#  'C674': 'Interfacing',
#  'C675': 'Logistics automation',
#  'C676': 'myria-',
#  'C677': 'Array controller based encryption',
#  'C678': 'Self-optimization',
#  'C679': 'Geniac',
#  'C68': 'Education education',
#  'C680': 'Cabin attendant',
#  'C681': 'Application actions',
#  'C682': 'Causal maps',
#  'C683': 'Maximum cost',
#  'C684': 'Event forecasting',
#  'C685': 'Turing test',
#  'C686': 'Transport layer',
#  'C687': 'Turing',
#  'C688': "Don't repeat yourself",
#  'C689': 'Rainflow-counting algorithm',
#  'C69': 'Multiple criterion optimization',
#  'C690': 'Earcon',
#  'C691': 'Twisted pair',
#  'C692': 'Deterministic simulation',
#  'C693': 'Ensemble forecasting',
#  'C694': 'Storage efficiency',
#  'C695': 'Field of view',
#  'C696': 'SNOBOL',
#  'C697': 'Seven Management and Planning Tools',
#  'C698': 'Business communication',
#  'C699': 'Physical security',
#  'C7': 'Computer vision',
#  'C70': 'Electronic board',
#  'C700': 'Small subgroup confinement attack',
#  'C701': 'Battleship',
#  'C702': 'Marine VHF radio',
#  'C703': 'Medical library',
#  'C704': 'Speech tempo',
#  'C705': 'Variational optimization',
#  'C706': 'Markovian discrimination',
#  'C707': 'Collaborative strategy',
#  'C708': 'Multi body',
#  'C709': 'Interleave sequence',
#  'C71': 'Cyclic network',
#  'C710': 'Andrew Project',
#  'C711': 'Set constraint',
#  'C712': 'Language sign',
#  'C713': 'Message type',
#  'C714': 'Muscle isotonic contraction',
#  'C715': 'Line Flush',
#  'C716': 'Employee number',
#  'C717': 'Digital reflex',
#  'C718': 'Object Title',
#  'C719': 'Body surface point',
#  'C72': 'System concept',
#  'C720': 'Quantitative Constraint',
#  'C721': 'Media print',
#  'C722': 'Path delay',
#  'C723': 'Closed loop testing',
#  'C724': 'Technical systems',
#  'C725': 'Service usage',
#  'C726': 'Set top box',
#  'C727': 'Distributed logic',
#  'C728': 'Path deviation',
#  'C729': 'Network strategy',
#  'C73': 'Organizational flexibility',
#  'C730': 'Inverse operation',
#  'C731': 'Text matching',
#  'C732': 'Relational system',
#  'C733': 'KiXtart',
#  'C734': 'Problem set',
#  'C735': 'CoreExpress',
#  'C736': 'Trust building',
#  'C737': 'Subjective quality',
#  'C738': 'Textural feature',
#  'C739': 'Link analysis',
#  'C74': 'Low Pin Count',
#  'C740': 'Gamma correction',
#  'C741': 'Method of exhaustion',
#  'C742': 'Morphing',
#  'C743': 'Wildcard',
#  'C744': 'Hot Chips',
#  'C745': 'Parameter identification problem',
#  'C746': 'Adaptive filter',
#  'C747': 'Brightness',
#  'C748': 'Order processing',
#  'C749': 'Substring',
#  'C75': 'Server-side',
#  'C750': 'RIKEN MDGRAPE-3',
#  'C751': 'Radon transform',
#  'C752': 'GiST',
#  'C753': 'Adaptive algorithm',
#  'C754': 'Hard disk drive failure',
#  'C755': 'Programming style',
#  'C756': 'Rework',
#  'C757': 'False alarm',
#  'C758': 'Switch-reference',
#  'C759': 'Face scanning',
#  'C76': 'Extensibility',
#  'C760': 'Guruswami–Sudan list decoding algorithm',
#  'C761': 'Standard function',
#  'C762': 'Programming algorithm',
#  'C763': 'Inquiry-based learning',
#  'C764': 'Project-based learning',
#  'C765': 'Iterative refinement',
#  'C766': 'ISCC–NBS system',
#  'C767': "Authors' rights",
#  'C768': 'Multiple visual images',
#  'C769': 'Stationary bike',
#  'C77': 'Dynamic programming',
#  'C770': 'Knowledge subject',
#  'C771': 'Watch Television',
#  'C772': 'Inheritance types',
#  'C773': 'Evacuation - action',
#  'C774': 'Balance walking',
#  'C775': 'Tags (device)',
#  'C776': 'Experience sharing',
#  'C777': 'Trust relationship',
#  'C778': 'Mobile app',
#  'C779': 'Content organization',
#  'C78': 'Eye tracking',
#  'C780': 'Information presentation',
#  'C781': 'Time sensitive',
#  'C782': 'Model reconstruction',
#  'C783': 'Application interface',
#  'C784': 'Gradient direction',
#  'C785': 'Travel mode',
#  'C786': 'Algebraic simplification',
#  'C787': 'Softmodem',
#  'C788': 'Keypad',
#  'C789': 'Lisp reader',
#  'C79': 'Uniform access principle',
#  'C790': 'All-to-all communication',
#  'C791': 'White Alice Communications System',
#  'C792': 'Multimodal interaction',
#  'C793': 'Very low frequency',
#  'C794': 'Pointer (computer programming)',
#  'C795': 'Kurtosis',
#  'C796': 'Air interface',
#  'C797': 'Image editing',
#  'C798': 'Real-time database',
#  'C799': 'Information capture',
#  'C8': 'Artificial intelligence',
#  'C80': 'Global optimum',
#  'C800': 'Electronic deception',
#  'C801': 'Modula',
#  'C802': 'Advanced Continuous Simulation Language',
#  'C803': 'Map regression',
#  'C804': 'Relational view',
#  'C805': 'Shared graphics memory',
#  'C806': 'Dynaset',
#  'C807': 'Shrink wrap contract',
#  'C808': 'Audicom',
#  'C809': 'Conjunctive adverb',
#  'C81': 'Space exploration',
#  'C810': 'Interpretability',
#  'C811': 'Egosurfing',
#  'C812': 'Plumbr',
#  'C813': 'Title bar',
#  'C814': 'Pressure suit',
#  'C815': 'Lexicostatistics',
#  'C816': 'Security token',
#  'C817': 'Container status',
#  'C818': 'Attention focus',
#  'C819': 'Collection selection',
#  'C82': 'Analysis of covariance',
#  'C820': 'Sound analysis',
#  'C821': 'Innovation theory',
#  'C822': 'Data patterns',
#  'C823': 'Volumetric model',
#  'C824': 'Targeted marketing',
#  'C825': 'Multi label learning',
#  'C826': 'Network application',
#  'C827': 'Execution cycle',
#  'C828': 'Crime forecasting',
#  'C829': 'Information life cycle',
#  'C83': 'Nominal group',
#  'C830': 'Negative sample',
#  'C831': 'Individual knowledge',
#  'C832': 'Conceptual mapping',
#  'C833': 'Electronic classroom',
#  'C834': 'Co innovation',
#  'C835': 'Suggested algorithm',
#  'C836': 'Autocorrelation',
#  'C837': 'Cerebro',
#  'C838': 'Trilateration',
#  'C839': 'Cycle detection',
#  'C84': 'Hierarchical database model',
#  'C840': 'Countersteering',
#  'C841': 'Context menu',
#  'C842': 'Unknown Source',
#  'C843': 'Hakka dialect',
#  'C844': 'Connection number',
#  'C845': 'Interaction interface',
#  'C846': 'Position bias',
#  'C847': 'Spondee',
#  'C848': 'Magnification',
#  'C849': 'Autonomous system (Internet)',
#  'C85': 'Mobility model',
#  'C850': 'Finger tracking',
#  'C851': 'Personal knowledge base',
#  'C852': 'Reasoning system',
#  'C853': 'Computational statistics',
#  'C854': 'Process simulation',
#  'C855': 'Emoticon',
#  'C856': 'Instruction set',
#  'C857': 'HP-IL',
#  'C858': 'Scientific community metaphor',
#  'C859': 'Unicast flood',
#  'C86': 'Smart switch',
#  'C860': 'Flowgorithm',
#  'C861': 'Hypsometric tints',
#  'C862': 'Recursively inseparable sets',
#  'C863': 'S band',
#  'C864': 'Magic circle',
#  'C865': 'Local Internet registry',
#  'C866': 'Structured ASIC platform',
#  'C867': 'Language form',
#  'C868': 'Simple speech',
#  'C869': 'White area',
#  'C87': '48-bit',
#  'C870': 'Fish eye',
#  'C871': 'Communication Response',
#  'C872': 'Report timing',
#  'C873': 'Test quality',
#  'C874': 'Interaction history',
#  'C875': 'Belief change',
#  'C876': 'Security validation',
#  'C877': 'Logical operations',
#  'C878': 'Remote diagnosis',
#  'C879': 'Design innovation',
#  'C88': 'Remote observation',
#  'C880': 'Remote management',
#  'C881': 'Indirect touch',
#  'C882': 'Motion prediction',
#  'C883': 'Structural representation',
#  'C884': 'Animal computer interaction',
#  'C885': 'Database query',
#  'C886': 'Global information',
#  'C887': 'Data capacity',
#  'C888': 'Base domain',
#  'C889': 'Local pattern',
#  'C89': 'Multiprotocol Encapsulation over ATM',
#  'C890': 'Predictive simulation',
#  'C891': 'Secure control',
#  'C892': 'Image code',
#  'C893': 'Differential algorithm',
#  'C894': 'Domain relation',
#  'C895': 'G.706',
#  'C896': 'Knowledge technology',
#  'C897': 'Landing page optimization',
#  'C898': 'Eye exercise',
#  'C899': 'Street (environment)',
#  'C9': 'Operating system',
#  'C90': 'Guess value',
#  'C900': 'Atomic operations',
#  'C901': 'Cyber threat',
#  'C902': 'Memory wall',
#  'C903': 'Remote computing',
#  'C904': 'Change prediction',
#  'C905': 'Multi frame',
#  'C906': 'Sequential programming',
#  'C907': 'Logical property',
#  'C908': 'Statistical Mode',
#  'C909': 'Function family',
#  'C91': 'Generalized TTL security mechanism',
#  'C910': 'Message frame',
#  'C911': 'Logic complexity',
#  'C912': 'Group decision-making',
#  'C913': 'Syntagmatic analysis',
#  'C914': 'Assertion',
#  'C915': 'Duplexer',
#  'C916': 'Memetics',
#  'C917': 'Programmed instruction',
#  'C918': 'APRS Calling',
#  'C919': 'El Farol Bar problem',
#  'C92': 'User-in-the-loop',
#  'C920': 'Programming assignment',
#  'C921': 'Joint weakness',
#  'C922': 'Reference management software',
#  'C923': 'High memory area',
#  'C924': 'Functional requirement',
#  'C925': 'Complex adaptive system',
#  'C926': 'Composite image filter',
#  'C927': 'Box modeling',
#  'C928': 'Semantic network',
#  'C929': 'Undefined variable',
#  'C93': 'Case Search',
#  'C930': 'Argument-dependent name lookup',
#  'C931': 'Pareto principle',
#  'C932': 'Minification',
#  'C933': 'Prime Directive',
#  'C934': 'Instructional design',
#  'C935': 'Tree structure',
#  'C936': 'Word lists by frequency',
#  'C937': 'Linear belief function',
#  'C938': 'AF-heap',
#  'C939': 'Amplitude modulation signalling system',
#  'C94': 'Numeric array',
#  'C940': 'Memory module',
#  'C941': 'Content format',
#  'C942': 'News Industry Text Format',
#  'C943': 'Self-diagnosis',
#  'C944': 'CMS EXEC',
#  'C945': 'Thai numerals',
#  'C946': 'Multi-touch',
#  'C947': 'Dependability',
#  'C948': 'Image registration',
#  'C949': 'Electronic signature',
#  'C95': 'Physical interface',
#  'C950': 'Biological data',
#  'C951': 'Machine discovery',
#  'C952': 'Data messages',
#  'C953': 'Balance design',
#  'C954': 'Virtual document',
#  'C955': 'Evacuation plan',
#  'C956': 'Universal closure',
#  'C957': 'Entropy criterion',
#  'C958': 'Tangent function',
#  'C959': 'Network migration',
#  'C96': 'Man machine communication',
#  'C960': 'Multi feature',
#  'C961': 'Text corpus',
#  'C962': 'Navigational instrument',
#  'C963': 'Member variable',
#  'C964': 'The purpose of a system is what it does',
#  'C965': 'Timeout',
#  'C966': 'Complementary colors',
#  'C967': 'Light field',
#  'C968': 'Leader election',
#  'C969': 'Voxel',
#  'C97': 'Capacity efficiency',
#  'C970': 'Dual_EC_DRBG',
#  'C971': 'Cookie stuffing',
#  'C972': 'tf–idf',
#  'C973': 'Backbone network',
#  'C974': 'Domain reduction',
#  'C975': 'Identity transform',
#  'C976': 'Database services',
#  'C977': 'String distance',
#  'C978': 'X.3',
#  'C979': 'Unicycle cart',
#  'C98': 'Cultural computing',
#  'C980': 'Google Ngram Viewer',
#  'C981': 'No-fly zone',
#  'C982': 'Bus contention',
#  'C983': 'Workload',
#  'C984': 'Threat assessment',
#  'C985': 'Load management',
#  'C986': 'Suppression list',
#  'C987': 'Built-in self-test',
#  'C988': 'Combining character',
#  'C989': 'Computation and Neural Systems',
#  'C99': 'Spectral shaping',
#  'C990': 'Smart key',
#  'C991': 'Survivability',
#  'C992': 'Microsoft Talisman',
#  'C993': 'Monitor unit',
#  'C994': 'Application sharing',
#  'C995': 'Normal vocal quality',
#  'C996': 'Training Deficiency',
#  'C997': 'Limbs movements',
#  'C998': 'Bike riding',
#  'C999': 'Method access',
#  'C1000': 'Device name',
#  ...}

# %% [markdown]
# Preparing a query. Note that this query will be used for all files, because of this we use placeholders for title (`#ARTICLE_TITLE`) and abstract (`#ARTICLE_ABSTRACT`) values. These placeholders will be automatically replaced with correct values for each of the processed file.
#
# To learn more about constructing queries, see the `querying_es.ipynb` notebook. Below we provide a simple query to demonstrate the processing batches of files.

# %%
query = {
  "query": {
    "dis_max": {
      "queries": [
        {
          "multi_match" : {
          "query":      "#ARTICLE_TITLE",  # PLACEHOLDER for an article title value (the same query for all files)
          "type":       "most_fields",
          "fields":     ["prefLabel^3", "related", "broader"],
          "tie_breaker": 0.5
         }
        },
        {
          "multi_match" : {
          "query":      "#ARTICLE_ABSTRACT", # PLACEHOLDER for an article abstract value (the same query for all files)
          "type":       "most_fields",
          "fields":     ["prefLabel^3", "related", "broader"],
          "tie_breaker": 0.5
         }
        }
      ]
    }
  }
}

# %% [markdown]
# `classify_input_files` is a function to query an ES index using a batch of files and the same query for all of them.
# It queries the index with a given `index_name` for each file from the `input_files_paths` list and retrieves a ranking of `n` best results with their scores.
#
# The results are saved in the `results` directory in two forms:
# - an original file with an object (that is **the best retrieved result** e.g., `ocs:C19`) of the `hasDiscipline` predicate updated in the `results/results` directory
# - a query result, a  `.ttl` file with a vocabulary containing data and the ranking retrieved from the query, in the `results/query_results` directory
#
# The input files are deleted (since their updated version is saved) by default. You can specify the `move_orignal` parameter as `False` to change this behavior.
# You can also set the `ask_to_override` parameters to `True` to make the function ask you whether to save the result after displaying it ([y/n]).
#
# It assumes that ES is running (if not start it, or see `env_setup.ipynb` for instructions) and an index is already constructed (see `loading_data_and_building_index.ipynb` for instructions).

# %%
with connect_elasticsearch({'host': 'localhost', 'port': PORT}) as es:
    classify_input_files(input_files_paths, labels_to_concepts_names, es, IDX_NAME, query, n=5, move_original=False, ask_to_override=True)
# Out:
# Yay Connected
# ###
# Parsing a next file 1/4:
# Query result for a file article0:
# [{'prefLabel': ['Sociology of the Internet'], 'score': 872.1316}, {'prefLabel': ['Suicide and the Internet'], 'score': 852.0229}, {'prefLabel': ['Outline of the Internet'], 'score': 836.8296}, {'prefLabel': ['Confusion of the inverse'], 'score': 833.3474}, {'prefLabel': ['Abundances of the elements'], 'score': 830.24585}]
# ###
# Parsing a next file 2/4:
# Query result for a file article1:
# [{'prefLabel': ['Brain tumor segmentation'], 'score': 379.25287}, {'prefLabel': ['Tumor segmentation'], 'score': 323.5705}, {'prefLabel': ['Liver tumor segmentation'], 'score': 321.0152}, {'prefLabel': ['Recurrent Gastrointestinal Stromal Tumor'], 'score': 302.49762}, {'prefLabel': ['Duodenal submucosal tumor'], 'score': 262.3456}]
# ###
# Parsing a next file 3/4:
# Query result for a file article2:
# [{'prefLabel': ['Suicide and the Internet'], 'score': 237.78304}, {'prefLabel': ['Programming in the large and programming in the small'], 'score': 222.99342}, {'prefLabel': ['Model in the loop'], 'score': 214.80319}, {'prefLabel': ['Software in the loop'], 'score': 214.80319}, {'prefLabel': ['Computers in the classroom'], 'score': 209.08588}]
# ###
# Parsing a next file 4/4:
# Query result for a file article3:
# [{'prefLabel': ['Suicide and the Internet'], 'score': 609.6226}, {'prefLabel': ['Confusion of the inverse'], 'score': 598.47327}, {'prefLabel': ['Abundances of the elements'], 'score': 578.6227}, {'prefLabel': ['The Victorian Internet'], 'score': 551.22833}, {'prefLabel': ['Sociology of the Internet'], 'score': 550.3605}]

# %%
with connect_elasticsearch({'host': 'localhost', 'port': PORT}) as es:
    classify_input_files(input_files_paths, labels_to_concepts_names, es, IDX_NAME, query, n=5)
# Out:
# Yay Connected
# ###
# Parsing a next file 1/4:
# Query result for a file article0:
# [{'prefLabel': ['Sociology of the Internet'], 'score': 872.1316}, {'prefLabel': ['Suicide and the Internet'], 'score': 852.0229}, {'prefLabel': ['Outline of the Internet'], 'score': 836.8296}, {'prefLabel': ['Confusion of the inverse'], 'score': 833.3474}, {'prefLabel': ['Abundances of the elements'], 'score': 830.24585}]
# Saving the result and updating the discipline with the best result.
# ###
# Parsing a next file 2/4:
# Query result for a file article1:
# [{'prefLabel': ['Brain tumor segmentation'], 'score': 379.25287}, {'prefLabel': ['Tumor segmentation'], 'score': 323.5705}, {'prefLabel': ['Liver tumor segmentation'], 'score': 321.0152}, {'prefLabel': ['Recurrent Gastrointestinal Stromal Tumor'], 'score': 302.49762}, {'prefLabel': ['Duodenal submucosal tumor'], 'score': 262.3456}]
# Saving the result and updating the discipline with the best result.
# ###
# Parsing a next file 3/4:
# Query result for a file article2:
# [{'prefLabel': ['Suicide and the Internet'], 'score': 237.78304}, {'prefLabel': ['Programming in the large and programming in the small'], 'score': 222.99342}, {'prefLabel': ['Model in the loop'], 'score': 214.80319}, {'prefLabel': ['Software in the loop'], 'score': 214.80319}, {'prefLabel': ['Computers in the classroom'], 'score': 209.08588}]
# Saving the result and updating the discipline with the best result.
# ###
# Parsing a next file 4/4:
# Query result for a file article3:
# [{'prefLabel': ['Suicide and the Internet'], 'score': 609.6226}, {'prefLabel': ['Confusion of the inverse'], 'score': 598.47327}, {'prefLabel': ['Abundances of the elements'], 'score': 578.6227}, {'prefLabel': ['The Victorian Internet'], 'score': 551.22833}, {'prefLabel': ['Sociology of the Internet'], 'score': 550.3605}]
# Saving the result and updating the discipline with the best result.
